# %% [markdown]
# ## 증상분류모델

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### 1. 질문을 학습 데이터로 사용하기 위해 텍스트 데이터 벡터화
# - 문맥을 반영하기위해 KBERT 모델 사용.

# %%
import pandas as pd

# %%
# 질문 데이터 불러오기
question_df = pd.read_csv('/content/drive/MyDrive/healthcare project/두통 질문.csv', index_col=0)
question_df
# Out:
#      disease_category disease_name intention  \
# 0                응급질환           두통        예방
# 1                응급질환           두통        예방
# 2                응급질환           두통        예방
# 3                응급질환           두통        예방
# 4                응급질환           두통        예방
# ...               ...          ...       ...
# 3423             응급질환           두통        치료
# 3424             응급질환           두통        치료
# 3425             응급질환           두통        치료
# 3426             응급질환           두통        치료
# 3427             응급질환           두통        치료
#
#                                                question
# 0                         두통 예방을 위해 어떤 자세나 활동이 도움이 될까요?
# 1         스트레스를 많이 받는 사람이 두통을 예방하기 위해 어떤 생활습관을 가져야 할까요?
# 2         대상포진 예방접종 후에 어지럼증과 두통이 예방접종과 관련이 있다면 어떻게 되나요?
# 3                    갈색세포증과 관련하여 일상생활에서 신경써야할 점은 무엇인가요?
# 4                      두통을 예방하기 위한 수면 자세에는 어떤 것들이 있을까요?
# ...                                                 ...
# 3423  두통과 스트레스 반응에 대한 급성 과민성을 진단하고 치료하는 방법에는 어떤 것들이 ...
# 3424       약국에서 구입 가능한 두통 치료제 중에서 어떤 것이 가장 효과적인지 알려주세요.
# 3425                   만성 두통을 치료하기 위해 어떤 방법이 있는지 알려주세요.
# 3426                      두통의 치료를 위해 어떤 약물이 사용될 수 있을까요?
# 3427        두통이 자주 생기는데, 이를 치료하기 위해 어떤 치료법을 사용할 수 있을까요?
#
# [3428 rows x 4 columns]

# %%
from sentence_transformers import SentenceTransformer

# KoSentence-BERT 모델 불러오기
model = SentenceTransformer('snunlp/KR-SBERT-V40K-klueNLI-augSTS')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.02k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/467M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/336k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/467M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/967k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# 벡터화(임베딩)
question_vec = model.encode(question_df['question'].tolist(), batch_size=32)

# %%
len(question_vec), question_vec[0]
# Out:
# (3428,
#  array([ 2.19613284e-01, -9.01607454e-01,  1.34280711e-01, -3.99087280e-01,
#         -6.56399131e-01,  2.89249718e-01, -2.18549475e-01, -1.20221782e+00,
#          3.31542462e-01, -2.51379460e-01, -1.19238615e+00, -8.10683250e-01,
#         -5.47765374e-01,  4.49536383e-01,  7.57921755e-01, -1.56103706e+00,
#          1.55002427e+00,  1.80459964e+00, -1.14636257e-01,  1.78722799e-01,
#         -6.56761289e-01,  4.59334999e-02,  6.14282310e-01, -3.36845756e-01,
#          3.92549664e-01, -7.37427294e-01,  5.98438382e-01, -7.11544156e-01,
#          4.54394892e-02,  1.25989103e+00, -4.30762440e-01,  7.18856812e-01,
#         -3.46938550e-01, -6.34605706e-01,  4.70853031e-01,  2.59704143e-01,
#         -2.77430594e-01, -1.96138900e-02, -7.47466683e-01, -5.03950655e-01,
#         -3.71224910e-01, -1.01627715e-01, -1.15113389e+00, -4.11175877e-01,
#         -1.41971648e+00,  2.33880386e-01, -3.18698287e-01,  5.84025085e-01,
#          5.56882918e-01, -1.88258793e-02,  1.52258766e+00, -3.60942483e-01,
#          7.11674690e-01,  5.99001944e-01,  1.76260501e-01, -3.31247061e-01,
#         -4.04283255e-01, -9.74037126e-02,  1.54910251e-01,  7.36179352e-01,
#         -1.50355017e+00,  5.77956319e-01,  3.10614616e-01,  1.14933677e-01,
#         -6.26879454e-01,  6.42552018e-01,  8.66898775e-01,  8.46095383e-01,
#         -4.19105232e-01, -9.17461097e-01,  2.05224246e-01,  9.99740303e-01,
#         -5.51510789e-02, -7.93135524e-01,  8.47758889e-01, -5.53470135e-01,
#         -2.25486420e-02,  1.06919102e-01,  5.89504004e-01, -7.89289236e-01,
#         -6.49492323e-01,  2.41628647e-01,  9.16502893e-01,  6.58516049e-01,
#         -1.88957691e-01,  7.45935645e-03,  8.42365503e-01,  2.42252082e-01,
#         -8.23157579e-02, -6.63035393e-01, -3.34965855e-01,  5.67943156e-01,
#          6.02169454e-01,  4.16878998e-01, -1.89409837e-01, -3.28359455e-01,
#         -3.18445265e-01,  1.00710101e-01, -5.45759618e-01,  3.90636712e-01,
#         -6.47159696e-01,  3.06657970e-01,  7.06554830e-01,  2.27092505e+00,
#          1.69118810e+00,  1.15517342e+00, -3.61310214e-01,  2.87737250e-01,
#          1.59208372e-01, -8.87150526e-01,  7.48314977e-01,  1.31356299e+00,
#          5.73817492e-01, -3.41294587e-01,  6.83760226e-01, -1.14895248e+00,
#         -5.57531774e-01,  8.01532790e-02,  4.12408039e-02,  7.96091035e-02,
#          9.12154138e-01,  5.45336366e-01, -1.38676631e+00,  4.02438603e-02,
#         -9.03831065e-01,  4.90990430e-01, -7.08449006e-01, -2.83932984e-01,
#         -5.64680517e-01, -6.04873657e-01,  4.41379696e-01, -7.25499494e-03,
#          9.66568366e-02, -2.36409441e-01,  1.99094445e-01, -2.47797623e-01,
#          1.13645755e-01,  3.69577855e-01,  5.33192575e-01, -7.31959403e-01,
#          3.05006385e-01, -7.70130754e-01,  6.36512756e-01, -3.93443704e-01,
#          1.32728469e+00,  7.54343092e-01, -1.54934391e-01,  1.23444498e+00,
#         -8.36928412e-02, -4.27919596e-01,  1.08758056e+00,  6.54176950e-01,
#         -8.70764017e-01, -7.76603460e-01, -1.12595432e-01, -6.35421455e-01,
#         -4.59124237e-01,  2.48493299e-01, -7.77769148e-01, -1.54683217e-01,
#         -5.00351656e-03, -2.70528913e-01,  1.17307991e-01,  7.01866448e-01,
#         -4.04729664e-01,  5.30176878e-01, -5.59004366e-01, -1.58265829e-01,
#         -2.65193284e-01,  3.62877190e-01,  1.06683481e+00, -2.59792805e-03,
#         -1.56286404e-01,  3.98155540e-01, -1.97360024e-01, -5.20617247e-01,
#          2.37165421e-01, -5.70173621e-01, -1.33144975e+00, -3.83311450e-01,
#         -8.49501908e-01, -1.47523236e+00,  5.51393270e-01,  2.80927539e-01,
#          7.88300753e-01,  9.07522202e-01,  1.46272913e-01,  1.59596646e+00,
#          9.80946235e-03,  5.84850669e-01, -1.24265563e+00, -6.94530070e-01,
#          1.03662872e+00, -5.11720061e-01, -6.67668998e-01,  5.31005204e-01,
#          1.43318117e-01, -4.58605111e-01,  2.55910218e-01,  8.93076777e-01,
#         -6.56897426e-01,  1.02273941e+00, -9.66089219e-02,  1.01227582e+00,
#          9.60822225e-01, -1.34444773e-01, -5.47648668e-01,  2.30334580e-01,
#          7.31600225e-01, -2.60282099e-01,  1.16563439e+00,  2.41217941e-01,
#          1.40248537e-02, -6.64148629e-01,  2.68522967e-02,  1.48769176e+00,
#          1.13200629e+00,  9.52934504e-01, -1.00274360e+00,  8.50498796e-01,
#          7.30030954e-01, -2.51957268e-01,  2.04088956e-01, -5.92030048e-01,
#         -3.95894349e-01, -6.59454688e-02, -9.20388222e-01,  5.14417648e-01,
#         -4.22153682e-01,  9.55555797e-01, -9.27799642e-01, -9.91824210e-01,
#         -1.91794798e-01, -1.21099508e+00, -9.53247070e-01,  9.40955997e-01,
#          3.28651100e-01,  1.58947244e-01,  6.95811033e-01,  1.23096578e-01,
#         -3.11716050e-01,  3.98821890e-01,  8.13797355e-01, -2.10695881e-02,
#          3.05086225e-01,  8.45982194e-01,  5.88164590e-02, -3.72905359e-02,
#          4.21937317e-01, -2.19603837e-01, -3.21979821e-01,  1.10631955e+00,
#          7.84629822e-01, -1.14094305e+00, -3.01688105e-01, -5.81709981e-01,
#         -7.78872132e-01, -1.08672336e-01,  8.27524066e-01, -4.71270144e-01,
#          2.01613799e-01, -4.83671933e-01, -5.87651253e-01,  8.18462431e-01,
#          4.14110005e-01, -9.92747366e-01,  6.61857069e-01,  9.04417455e-01,
#          2.80407250e-01, -1.29150069e+00,  7.58366659e-02, -1.03918123e+00,
#         -8.98956895e-01,  4.44184095e-01,  8.43108118e-01, -6.56464338e-01,
#          8.71239230e-03,  3.72946471e-01,  2.00382531e-01,  1.07381105e+00,
#         -1.11191106e+00, -9.51963544e-01, -6.16293371e-01,  1.79026246e+00,
#          8.22990775e-01,  3.28210205e-01,  6.77078590e-02, -6.18708730e-01,
#         -1.23624289e+00,  4.34644967e-01,  3.40200961e-01, -1.53667283e+00,
#          8.06759477e-01, -6.05227351e-01, -1.39580026e-01,  6.25707269e-01,
#         -7.24083558e-02,  7.86218882e-01, -4.35567975e-01,  2.37231389e-01,
#          7.25331068e-01, -1.92033201e-01, -5.73513508e-01,  1.88263690e+00,
#          8.98427010e-01, -4.62316960e-01, -2.01915368e-01,  1.08200145e+00,
#         -7.70529628e-01, -5.39586961e-01,  5.05908906e-01, -7.80655801e-01,
#         -4.13938522e-01, -1.62843013e+00, -6.41044736e-01, -1.12433410e+00,
#          9.42689240e-01,  7.71017194e-01,  4.70880330e-01,  1.56254030e-03,
#          3.82028520e-01,  5.06665528e-01, -1.66453481e+00,  9.65481162e-01,
#         -2.33136322e-02,  6.31807089e-01,  4.15253907e-01,  9.26366568e-01,
#          5.00726342e-01,  8.85675728e-01,  6.14720583e-01,  8.43103111e-01,
#         -4.13641185e-01, -1.07954454e+00,  3.23740512e-01, -1.99026167e-01,
#          6.29696608e-01,  1.39068663e+00,  6.93292618e-01, -1.65785706e+00,
#          9.69605744e-01, -7.66496509e-02, -2.78185248e-01,  5.29540300e-01,
#         -8.10963750e-01, -1.34122407e+00, -7.82254934e-01,  6.43477559e-01,
#          3.27918589e-01, -5.23038983e-01, -3.25436950e-01, -6.76404357e-01,
#         -5.01834154e-01,  9.43707705e-01,  9.04223680e-01,  6.63585067e-01,
#         -8.05692971e-01, -6.08660281e-01,  5.68469644e-01,  1.24375381e-01,
#          6.31549716e-01,  3.60511303e-01,  4.61907387e-01, -4.80877608e-01,
#         -2.68608063e-01,  1.00679386e+00, -1.21005142e+00,  2.86452889e-01,
#          7.54071295e-01,  3.10324550e-01, -4.18304086e-01,  9.21634734e-01,
#          6.11349791e-02, -4.41741385e-02, -5.98567426e-01, -1.54824090e+00,
#         -5.14581621e-01,  7.66489029e-01,  4.45536494e-01, -1.16095078e+00,
#         -1.23375006e-01, -6.72113955e-01, -1.89865991e-01,  2.30180830e-01,
#         -3.08179259e-01,  2.04632372e-01, -3.25280160e-01, -1.67190731e-01,
#          1.73643553e+00, -5.57373948e-02,  5.26998162e-01,  4.14451420e-01,
#          1.17320657e-01, -2.25468233e-01,  2.23987848e-01, -9.36683416e-02,
#          1.11885108e-01,  5.88400304e-01, -7.10364699e-01, -1.21467829e+00,
#          8.24364126e-01, -2.36521006e-01, -2.74922818e-01,  8.01048994e-01,
#          1.42098919e-01,  3.21572036e-01,  7.83543468e-01,  5.90025634e-02,
#         -8.74267370e-02,  4.84795898e-01,  4.83223647e-02, -2.32620940e-01,
#          1.73748150e-01, -4.60974842e-01,  5.04080951e-01,  9.78703424e-02,
#          3.12033594e-01,  5.61682642e-01, -5.41248441e-01, -1.70438215e-01,
#          4.51509327e-01, -1.09982237e-01,  3.03970218e-01,  1.37778342e-01,
#         -1.91553727e-01,  2.39490882e-01,  3.32734793e-01, -2.63163984e-01,
#          2.72640109e-01, -9.74075973e-01, -4.70386297e-01, -3.96726951e-02,
#         -1.41426468e+00, -4.22679693e-01,  4.69869077e-01, -3.25499237e-01,
#         -7.47968078e-01, -1.29114673e-01,  3.74417514e-01, -5.23178577e-01,
#         -4.53559995e-01, -8.13681006e-01,  1.15089500e+00,  3.51870239e-01,
#         -2.57098228e-01,  4.69607152e-02,  1.44432068e-01, -1.43864229e-01,
#         -5.67343593e-01, -7.19138801e-01, -1.15598893e+00,  1.80564731e-01,
#         -3.14232081e-01, -5.57042062e-01,  6.24076188e-01, -1.34947336e+00,
#         -9.54787910e-01, -6.36460841e-01, -1.93480834e-01,  1.86938960e-02,
#          2.75335640e-01, -4.05623883e-01, -3.33342284e-01,  2.84712523e-01,
#          3.83213341e-01,  1.41454652e-01, -1.57980472e-01,  2.93567449e-01,
#          6.76996887e-01, -9.45702314e-01,  8.43978822e-01, -3.81624401e-01,
#          7.82262862e-01,  3.24823335e-02, -3.06515694e-01,  3.42938960e-01,
#         -2.14528143e-01,  5.27728975e-01, -7.58777916e-01,  3.78328294e-01,
#          9.54219759e-01, -1.04135901e-01, -1.19943365e-01,  3.68103608e-02,
#         -4.43327904e-01,  4.63630527e-01, -2.20104858e-01, -4.25232381e-01,
#          2.11996064e-01,  1.74596131e-01,  9.31218341e-02, -9.92287576e-01,
#         -4.19421494e-01,  4.66697216e-01, -7.96198487e-01, -6.80281281e-01,
#          2.57595718e-01, -4.88716155e-01,  4.49431479e-01,  6.73650444e-01,
#         -7.34075427e-01,  7.31473029e-01, -1.21195662e+00, -3.77873778e-01,
#         -4.96244401e-01, -6.54122353e-01, -3.86681497e-01, -1.01034212e+00,
#          1.04481518e+00,  3.96408379e-01,  6.76908135e-01, -4.36168611e-01,
#         -7.83730149e-01, -7.05416739e-01, -6.90765083e-01,  7.86882818e-01,
#         -3.40958297e-01, -3.77974093e-01,  4.30293977e-01, -1.00361037e+00,
#         -1.25079870e+00, -3.90669465e-01, -9.95208174e-02,  8.54161859e-01,
#         -5.36974519e-02, -6.74255610e-01, -9.30299461e-02, -3.03488374e-01,
#         -2.58110404e-01,  1.38233483e+00, -1.51144147e+00, -6.24242187e-01,
#         -5.51596522e-01, -5.57931542e-01,  3.12740169e-02, -3.37426186e-01,
#          1.55410326e+00, -4.12849873e-01,  8.25949967e-01,  8.82157236e-02,
#         -6.44951582e-01,  3.18506882e-02, -8.21937203e-01,  2.31725439e-01,
#          1.13133025e+00, -1.66503191e-01,  1.15689051e+00, -3.42086583e-01,
#         -4.81290013e-01, -6.97634518e-02,  1.16711462e+00,  4.68300670e-01,
#          1.84669599e-01, -1.23285294e-01, -1.85550964e+00, -1.57129988e-01,
#          1.64806950e+00, -1.62038818e-01, -6.28980935e-01,  6.17710769e-01,
#          7.47638106e-01,  7.52586648e-02, -1.55291963e+00,  2.69449323e-01,
#          5.88459969e-02, -4.95145649e-01,  5.82838021e-02,  5.11888862e-01,
#          2.89752364e-01,  5.44064462e-01,  4.09270287e-01, -2.08457578e-02,
#          1.27026498e-01, -5.15805840e-01,  2.20628887e-01,  2.76764512e-01,
#         -1.50493038e+00,  5.17344713e-01,  9.00592923e-01,  3.91445309e-01,
#         -6.59332126e-02,  3.04452300e-01, -3.50036398e-02, -2.24893093e-02,
#         -6.27446100e-02,  1.03479373e+00,  6.11875415e-01, -8.60636652e-01,
#         -3.35650921e-01, -4.99272823e-01,  5.22862554e-01, -6.67085648e-01,
#          7.30201304e-01,  5.58758140e-01,  7.35675916e-02, -6.57468736e-01,
#         -7.78994620e-01,  1.07166404e-02, -1.00537765e+00,  9.37507674e-02,
#         -1.86027780e-01,  6.18273377e-01,  7.09471643e-01,  1.10005021e+00,
#          9.83407974e-01,  1.32458580e+00, -1.86337247e-01,  5.70895493e-01,
#          6.62064791e-01, -3.06131512e-01,  4.00558174e-01,  2.48856172e-01,
#         -5.38366079e-01, -5.34941435e-01,  4.83937055e-01, -5.39084570e-03,
#         -1.67597253e-02, -1.42842293e-01, -4.53390956e-01, -1.26714122e+00,
#          4.08040553e-01, -2.02112809e-01,  6.71887755e-01,  1.46914274e-01,
#          6.45061612e-01,  7.14276373e-01, -4.15387094e-01,  1.98252171e-01,
#          4.24348533e-01,  3.64891857e-01, -1.29467398e-01, -6.30523622e-01,
#         -6.69130027e-01, -7.26347864e-01, -1.08850002e+00, -8.54489654e-02,
#         -2.56528944e-01,  7.95566440e-01,  1.64325684e-01,  6.85758352e-01,
#          5.25762960e-02, -4.49508995e-01,  7.74026990e-01, -7.65989348e-02,
#          6.81074202e-01, -1.63406849e-01, -4.27747130e-01, -2.26188991e-02,
#          1.00528133e+00,  2.95251638e-01,  8.42569545e-02,  1.46016136e-01,
#         -5.09965539e-01,  3.87319922e-01,  1.96353300e-03, -3.03136677e-01,
#         -5.33540189e-01,  6.99966311e-01,  7.35660851e-01,  1.10131353e-01,
#         -1.17932332e+00,  2.02618107e-01, -1.57828003e-01, -7.96044394e-02,
#         -9.79486763e-01,  3.70633006e-01, -1.91450059e-01, -6.38721883e-02,
#          1.42939940e-01, -1.45051375e-01, -2.76625305e-01, -3.31238508e-02,
#         -7.13941574e-01, -3.97815853e-01, -1.06017463e-01, -5.32947123e-01,
#          2.90575791e-02,  1.40639946e-01, -6.98365211e-01, -4.90016580e-01,
#          1.75958306e-01, -2.84062207e-01,  1.43847972e-01,  4.97186154e-01,
#         -8.04356813e-01, -9.61297750e-03,  1.11485250e-01,  3.04249495e-01,
#          2.69154131e-01, -5.66357255e-01,  8.05661500e-01, -6.66228950e-01,
#         -6.51736319e-01, -1.16933465e-01,  8.29180956e-01, -7.98883066e-02,
#         -2.78681427e-01,  1.87734056e+00, -6.78049698e-02, -1.03447688e+00,
#         -5.03999442e-02,  1.33605170e+00,  1.74326748e-01, -1.18482578e+00,
#          6.02372766e-01, -1.10079741e+00, -9.81736541e-01, -1.18642056e+00,
#          6.43421590e-01, -1.13562727e+00, -2.80044377e-01, -1.12523770e+00,
#          3.66785824e-01, -9.40015852e-01, -1.29549229e+00,  6.29473746e-01,
#         -4.42136765e-01, -2.65850008e-01, -9.49191928e-01,  6.57697558e-01,
#          3.76734138e-01,  9.95932966e-02,  5.63871920e-01,  4.73569870e-01,
#         -2.85559684e-01, -1.79463640e-01, -7.57189691e-01,  6.03651464e-01,
#         -3.55499268e-01, -7.01632798e-02, -9.83147323e-02,  1.47125101e+00,
#          3.59626353e-01, -7.81656429e-02,  1.26614869e+00,  7.80503213e-01,
#         -2.41301134e-01,  9.59767580e-01, -6.32188201e-01, -8.47126395e-02,
#          1.97184637e-01, -3.45368505e-01,  7.86265016e-01,  1.28918111e-01,
#         -8.26658845e-01,  3.42777409e-02,  1.45780134e+00, -5.21397293e-01,
#         -8.30261528e-01,  6.56150103e-01, -1.27350152e+00, -5.21833450e-02,
#         -1.52601651e-03, -1.20309854e+00, -2.14337096e-01, -7.47718751e-01,
#         -4.66134489e-01, -1.21551221e-02,  4.95777726e-01, -6.50524735e-01,
#          2.20243767e-01,  6.74562007e-02,  3.06765139e-01, -3.08786094e-01,
#          7.88489431e-02,  2.01921850e-01, -6.11548007e-01,  2.11383134e-01],
#        dtype=float32))

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le_intention = le.fit_transform(question_df['intention']) # Series를 2D 배열로

# %%
question_df['intention'].unique()
# Out:
# array(['예방', '원인', '정의', '증상', '진단', '치료'], dtype=object)

# %%
# 라벨 변환 결과 확인인
le_intention
# Out:
# array([0, 0, 0, ..., 5, 5, 5])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
X = question_vec
y = le_intention

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
param_grid = {
    'n_estimators': [150, 200, 250, 300], # 트리의 개수
    'max_depth': [10, 15, 20] # 트리 하나당 분류를 시도하는 질문의 개수
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=13), param_grid, cv=5) # cv=5: 5개의 fold로 k-fold 교차검증
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=13),
#              param_grid={'max_depth': [10, 15, 20],
#                          'n_estimators': [150, 200, 250, 300]})

# %%
result = pd.DataFrame(grid_search.cv_results_)
result.head(2)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       7.134927      0.085203         0.026170        0.000823
# 1       9.518633      0.177767         0.034524        0.000670
#
#    param_max_depth  param_n_estimators  \
# 0               10                 150
# 1               10                 200
#
#                                    params  split0_test_score  \
# 0  {'max_depth': 10, 'n_estimators': 150}           0.825137
# 1  {'max_depth': 10, 'n_estimators': 200}           0.830601
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.837887           0.875912           0.810219           0.817518
# 1           0.836066           0.874088           0.817518           0.819343
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.833335        0.023175               12
# 1         0.835523        0.020483                9

# %%
result[['param_n_estimators', 'params', 'mean_test_score']]
# Out:
#     param_n_estimators                                  params  \
# 0                  150  {'max_depth': 10, 'n_estimators': 150}
# 1                  200  {'max_depth': 10, 'n_estimators': 200}
# 2                  250  {'max_depth': 10, 'n_estimators': 250}
# 3                  300  {'max_depth': 10, 'n_estimators': 300}
# 4                  150  {'max_depth': 15, 'n_estimators': 150}
# 5                  200  {'max_depth': 15, 'n_estimators': 200}
# 6                  250  {'max_depth': 15, 'n_estimators': 250}
# 7                  300  {'max_depth': 15, 'n_estimators': 300}
# 8                  150  {'max_depth': 20, 'n_estimators': 150}
# 9                  200  {'max_depth': 20, 'n_estimators': 200}
# 10                 250  {'max_depth': 20, 'n_estimators': 250}
# 11                 300  {'max_depth': 20, 'n_estimators': 300}
#
#     mean_test_score
# 0          0.833335
# 1          0.835523
# 2          0.835521
# 3          0.835157
# 4          0.847920
# 5          0.850106
# 6          0.848283
# 7          0.851203
# 8          0.848284
# 9          0.847193
# 10         0.848652
# 11         0.847557

# %%
y_pred = grid_search.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.858600583090379

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 57,   2,   0,   1,   2,   3],
#        [  0, 110,   1,   5,   2,   1],
#        [  0,   7, 101,  11,   7,   0],
#        [  0,   6,   8, 144,   6,   1],
#        [  0,   5,   2,   6, 114,   3],
#        [  3,   1,   1,   5,   8,  63]])

# %% [markdown]
# #### 2. 벡터화된 질문의 차원이 크므로 학습시 성능이 좋지않을 수 있어 차원 축소 진행

# %% [markdown]
# - 차원축소: pca, 모델: RandomForestClassifier
# - 차원을 늘려도 정확도 향상이 거의 없음.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# 정규화
question_ss = StandardScaler().fit_transform(question_vec)

# pca
pca = PCA(n_components=50) # 축소할 차원의 개수
question_pca = pca.fit_transform(question_ss)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.11609709, 0.07995649, 0.06058289, 0.05276635, 0.03648964,
#        0.03374185, 0.02736324, 0.02351206, 0.02223818, 0.01941289,
#        0.01877341, 0.01766712, 0.01621959, 0.0148197 , 0.01443115,
#        0.01414343, 0.01276166, 0.01238262, 0.01136667, 0.01116493,
#        0.01064634, 0.0099815 , 0.00926424, 0.00912638, 0.00895888,
#        0.00823751, 0.00785143, 0.00757601, 0.00737708, 0.00698274,
#        0.00666826, 0.00640627, 0.00622595, 0.00617228, 0.00607353,
#        0.00573565, 0.00556177, 0.0054169 , 0.00509097, 0.00507568,
#        0.00487577, 0.00472585, 0.00460258, 0.00438011, 0.00414433,
#        0.00400497, 0.00393255, 0.00381603, 0.00369491, 0.00364251],
#       dtype=float32)

# %%
# 축소된 차원이 원본 변동성의 약 80%를 설명함.
a = 0
for n in pca.explained_variance_ratio_:
    a += n
a
# Out:
# 0.8021399297285825

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import GridSearchCV

# %%
X = question_pca
y = le_intention

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# clf = RandomForestClassifier(n_estimators=100, random_state=13)

param_grid = {
    'n_estimators': [200, 250, 300], # 트리의 개수
    'max_depth': [10, 15, 20], # 트리 하나당 분류를 시도하는 질문의 개수
    'min_samples_split': [2, 4], # 노드를 나누기 위해 필요한 최소한의 sample 개수
    'min_samples_leaf': [2, 4], # 노드를 나눈 후 생성된 각 노드에 필요한 최소 샘플 수
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=13), param_grid, cv=5) # cv=5: 5개의 fold로 k-fold 교차검증
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=13),
#              param_grid={'max_depth': [10, 15, 20], 'min_samples_leaf': [2, 4],
#                          'min_samples_split': [2, 4],
#                          'n_estimators': [200, 250, 300]})

# %%
y_pred = grid_search.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.858600583090379

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 57,   2,   0,   0,   2,   4],
#        [  0, 107,   2,   7,   2,   1],
#        [  0,   7, 100,  10,   9,   0],
#        [  0,   8,   6, 144,   7,   0],
#        [  0,   5,   2,   5, 116,   2],
#        [  3,   0,   1,   2,  10,  65]])

# %%
n_components = [50, 100, 150]
best_score = 0
bestpca = None

# 정규화
scaler = StandardScaler()
question_ss = scaler.fit_transform(question_vec)

X = question_ss
y = le_intention
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

for n in n_components:

    # pca
    pca = PCA(n_components = n)
    X_train = pca.fit_transform(X_train_raw)
    X_test = pca.transform(X_test_raw) # X_train에서 학습한 pca 변환을 그대로 사용해야하므로 transform만 사용


    param_grid = {
    'n_estimators': [200, 250, 300], # 트리의 개수
    'max_depth': [10, 15, 20], # 트리 하나당 분류를 시도하는 질문의 개수
    }

    grid_search = GridSearchCV(RandomForestClassifier(random_state=13), param_grid, cv=5) # cv=5: 5개의 fold로 k-fold 교차검증
    grid_search.fit(X_train, y_train)

    y_pred = grid_search.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    if accuracy > best_score:
        best_score = accuracy
        bestpca = n

print('축소한 차원수:', bestpca, '모델 파라미터:', grid_search.best_params_, '정확도:', best_score)

# %%
confusion_matrix(y_test, y_pred)

# %% [markdown]
# - 차원축소: pca, 모델: XGBoost

# %%
pca_xg = PCA(n_components = 150)
X_train = pca_xg.fit_transform(X_train_raw)
X_test = pca_xg.transform(X_test_raw)

# %%
from xgboost import XGBClassifier

param_grid = {
    'n_estimators': [100, 200, 300],  # 트리 개수
    'max_depth': [5, 10, 15],  # 최대 깊이
    'learning_rate': [0.01, 0.05, 0.1]  # 학습률
}

xgb = XGBClassifier(random_state=13)

grid_search = GridSearchCV(xgb, param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...ne,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=13, ...),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [5, 10, 15],
#                          'n_estimators': [100, 200, 300]})

# %%
grid_search.best_params_, grid_search.best_score_
# Out:
# ({'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300},
#  0.8559424567561459)

# %%
y_pred = grid_search.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8702623906705539

# %% [markdown]
# - RandomForestClassifier, XGBoost 모델 성능 차이가 거의 없어 코드 실행이 비교적 빨리되는 RandomForestClassifier로 선택

# %% [markdown]
# #### 3. 모델 저장 및 재사용

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix

n_components = [50, 100, 150]
best_score = 0
bestpca = None

# 정규화
scaler = StandardScaler()
question_ss = scaler.fit_transform(question_vec)

X = question_ss
y = le_intention
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

for n in n_components:

    # pca
    pca = PCA(n_components = n)
    X_train = pca.fit_transform(X_train_raw)
    X_test = pca.transform(X_test_raw) # X_train에서 학습한 pca 변환을 그대로 사용해야하므로 transform만 사용


    param_grid = {
    'n_estimators': [200, 250, 300], # 트리의 개수
    'max_depth': [10, 15, 20], # 트리 하나당 분류를 시도하는 질문의 개수
    }

    grid_search = GridSearchCV(RandomForestClassifier(random_state=13), param_grid, cv=5) # cv=5: 5개의 fold로 k-fold 교차검증
    grid_search.fit(X_train, y_train)

    y_pred = grid_search.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    if accuracy > best_score:
        best_score = accuracy
        bestpca = n

print('축소한 차원수:', bestpca, '모델 파라미터:', grid_search.best_params_, '정확도:', best_score)
# Out:
# 축소한 차원수: 150 모델 파라미터: {'max_depth': 20, 'n_estimators': 300} 정확도: 0.8775510204081632

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=300, random_state=13)

# %%
import joblib

# 모델 저장
joblib.dump(grid_search.best_estimator_, '/content/drive/MyDrive/healthcare project/headache_randomforest.pkl') #best_estimator_ 는 학습이 완료된 모델 객체이다.
joblib.dump(pca, '/content/drive/MyDrive/healthcare project/headache_pca.pkl')
joblib.dump(scaler, '/content/drive/MyDrive/healthcare project/headache_scaler.pkl')
# Out:
# ['/content/drive/MyDrive/healthcare project/headache_scaler.pkl']

# %%
# 저장된 RandomForestClassifier 모델 불러오기
loaded_model = joblib.load('/content/drive/MyDrive/healthcare project/headache_randomforest.pkl')

# 예측 수행
y_pred = loaded_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8775510204081632

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 59,   1,   0,   0,   1,   4],
#        [  0, 108,   1,   7,   2,   1],
#        [  0,   6, 102,  10,   8,   0],
#        [  0,   4,   5, 152,   4,   0],
#        [  0,   5,   2,   5, 116,   2],
#        [  2,   1,   0,   4,   9,  65]])
